# %%
import pandas as pd

# %%
music_list = pd.read_csv('data/top1000_new_tokenizing.csv')

# %%
music_list
# Out:
#       Unnamed: 0.1  Unnamed: 0  melon_music_code                     제목  \
# 0                0           0          35383397      그때 그 순간 그대로 (그그그)
# 1                1           1          34657844                 사랑인가 봐
# 2                2           2          34943312                 나의 X에게
# 3                3           3          34787226                내가 아니라도
# 4                4           4          34061322              사랑은 늘 도망가
# ...            ...         ...               ...                    ...
# 6521          6521        6521          33151943  paranoid (Feat. DEAN)
# 6522          6522        6522          33509132   꿈 (Still I Love You)
# 6523          6523        6523          33572058                 서투른 고백
# 6524          6524        6524          32613630                     연가
# 6525          6525        6525          33221082                     소등
#
#                 가수            장르  \
# 0     WSG워너비 (가야G)           발라드
# 1             멜로망스    발라드, 국내드라마
# 2               경서           발라드
# 3               주호           발라드
# 4              임영웅    발라드, 국내드라마
# ...            ...           ...
# 6521         Mokyo        포크/블루스
# 6522           김수영  인디음악, 포크/블루스
# 6523           그_냥  인디음악, 포크/블루스
# 6524            정우  인디음악, 포크/블루스
# 6525           109  인디음악, 포크/블루스
#
#                                                      가사  \
# 0     잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1     너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3     사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...                                                 ...
# 6521  So I got paranoid with the drums I ain’t got t...
# 6522  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
# [6526 rows x 8 columns]

# %%
music_list.drop(['Unnamed: 0', 'Unnamed: 0.1'], inplace=True, axis=1)
music_list
# Out:
#       melon_music_code                     제목            가수            장르  \
# 0             35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)           발라드
# 1             34657844                 사랑인가 봐          멜로망스    발라드, 국내드라마
# 2             34943312                 나의 X에게            경서           발라드
# 3             34787226                내가 아니라도            주호           발라드
# 4             34061322              사랑은 늘 도망가           임영웅    발라드, 국내드라마
# ...                ...                    ...           ...           ...
# 6521          33151943  paranoid (Feat. DEAN)         Mokyo        포크/블루스
# 6522          33509132   꿈 (Still I Love You)           김수영  인디음악, 포크/블루스
# 6523          33572058                 서투른 고백           그_냥  인디음악, 포크/블루스
# 6524          32613630                     연가            정우  인디음악, 포크/블루스
# 6525          33221082                     소등           109  인디음악, 포크/블루스
#
#                                                      가사  \
# 0     잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1     너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3     사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...                                                 ...
# 6521  So I got paranoid with the drums I ain’t got t...
# 6522  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
# [6526 rows x 6 columns]

# %%
music_list.values
# Out:
# array([[35383397, '그때 그 순간 그대로 (그그그)', 'WSG워너비 (가야G)', '발라드',
#         '잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는데 반가움에 멍해졌죠  생각보다 오래 된 것 같은 우리 수다스럽던 그때가 생각나 뭐가 그렇게도 할 말이 많아서 밤을 지새우곤 했죠  그리운 목소리 그리던 얼굴 참 많이도 기다렸어  다시 만나자는 너의 한마디에 울컥 눈물이 나 결국 너였단 걸  알아 기다림의 끝은 기적이 되고 기적 같은 우린 운명처럼  서로를 알아보고 그렇게 눈앞에 서있죠  우리 사랑했던 우리 다시 만나 그때 그 순간 그대로 사랑했고 사랑할 거니까  같이 듣던 노래 그때 그 거리를 이제 혼자 아닌 너와 둘이 걸어  다시 오른쪽에 나란히 발맞춰 같은 노래를 부르죠  그리운 만남을 그리던 날들 참 많이도 기다렸어  다시 너를 만나 더욱 더 소중해 같은 마음이란 걸  알아 기다림의 끝은 기적이 되고 기적 같은 우린 운명처럼  서로를 알아보고 그렇게 눈앞에 서있죠  우리 사랑했던 우리 다시 만나 그때 그 순간 그대로  사랑했고 사랑할 거니까  처음 느낌 그대로 설렘이 가득한 날  고마워 다시 돌아와줘서  그때 그 순간처럼 날  안아줘  결국 기다림의 끝은 기적이 되고 기적 같은 우린 운명처럼  서로를 알아보고 그렇게 눈앞에 서있죠  우리 사랑했던 우리 다시 만나 그때 그 순간 그대로  사랑했고 사랑할 거니까',
#         "['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아', '보여', '인사', '나누며', '사실', '궁금한', '게', '너무', '많았는데', '반가', '움', '에', '멍해졌죠', '생각', '보다', '오래', '된', '것', '같은', '우리', '수다', '스럽던', '그때', '가', '생각나', '뭐', '가', '그렇게도', '할', '말', '이', '많아서', '밤', '을', '지', '새우', '곤', '했죠', '그리운', '목소리', '그리던', '얼굴', '참', '많이', '도', '기다렸어', '다시', '만나자는', '너', '의', '한마디', '에', '울컥', '눈물', '이', '나', '결국', '너', '였단', '걸', '알', '아', '기다림', '의', '끝', '은', '기적', '이', '되고', '기적', '같은', '우린', '운명', '처럼', '서로', '를', '알아보고', '그렇게', '눈앞', '에', '서있죠', '우리', '사랑', '했던', '우리', '다시', '만나', '그때', '그', '순간', '그대로', '사랑', '했고', '사랑', '할', '거', '니까', '같이', '듣던', '노래', '그때', '그', '거리', '를', '이제', '혼자', '아닌', '너', '와', '둘', '이', '걸어', '다시', '오른쪽', '에', '나란히', '발', '맞춰', '같은', '노래', '를', '부르죠', '그리운', '만남', '을', '그리던', '날', '들', '참', '많이', '도', '기다렸어', '다시', '너', '를', '만나', '더욱', '더', '소중해', '같은', '마음', '이란', '걸', '알', '아', '기다림', '의', '끝', '은', '기적', '이', '되고', '기적', '같은', '우린', '운명', '처럼', '서로', '를', '알아보고', '그렇게', '눈앞', '에', '서있죠', '우리', '사랑', '했던', '우리', '다시', '만나', '그때', '그', '순간', '그대로', '사랑', '했고', '사랑', '할', '거', '니까', '처음', '느낌', '그대로', '설렘이', '가득한', '날', '고마워', '다시', '돌아와줘서', '그때', '그', '순간', '처럼', '날', '안아줘', '결국', '기다림', '의', '끝', '은', '기적', '이', '되고', '기적', '같은', '우린', '운명', '처럼', '서로', '를', '알아보고', '그렇게', '눈앞', '에', '서있죠', '우리', '사랑', '했던', '우리', '다시', '만나', '그때', '그', '순간', '그대로', '사랑', '했고', '사랑', '할', '거', '니까']"],
#        [34657844, '사랑인가 봐', '멜로망스', '발라드, 국내드라마',
#         '너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습을 보고 있으면 자연스레 따라 웃고 있는 걸 너의 행동에 설레어하고 뒤척이다가 지새운 밤이 많아지는데 이건 누가 봐도 사랑일 텐데 종일 함께면 질릴 텐데 나 돌아서도 온통 너인 건 아무래도 사랑인가 봐 점점 너와 하고 싶은 일들 생각하면서 하룰 보낸 날이 많아지는데 이건 누가 봐도 사랑일 텐데 종일 함께면 질릴 텐데 나 돌아서도 온통 너인 건 아무래도 사랑인가 봐 너의 행복해하는 모습을 보고 있으면 나도 모르게 따라 웃는데 이 정도면 알아줄 만하잖아 너도 용기 낼만 하잖아 나만 이런 게 아니라면 우리 만나볼 만하잖아 아무래도 사랑인가 봐',
#         "['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상상', '하는', '게', '요즘', '내', '일상', '이', '되고', '너', '의', '즐거워하는', '모습', '을', '보고', '있으면', '자연스레', '따라', '웃고', '있는', '걸', '너', '의', '행동', '에', '설레어하고', '뒤척', '이', '다가', '지', '새', '운', '밤', '이', '많아지는데', '이건', '누가', '봐도', '사랑', '일', '텐데', '종일', '함께면', '질릴', '텐데', '나', '돌아서도', '온통', '너', '인', '건', '아무래도', '사랑', '인가', '봐', '점점', '너', '와', '하고', '싶은', '일', '들', '생각', '하면서', '하', '룰', '보낸', '날', '이', '많아지는데', '이건', '누가', '봐도', '사랑', '일', '텐데', '종일', '함께면', '질릴', '텐데', '나', '돌아서도', '온통', '너', '인', '건', '아무래도', '사랑', '인가', '봐', '너', '의', '행복해하는', '모습', '을', '보고', '있으면', '나도', '모르게', '따라', '웃는데', '이', '정도', '면', '알아줄', '만', '하잖아', '너', '도', '용기', '낼', '만', '하잖아', '나', '만', '이런', '게', '아니라면', '우리', '만', '나볼', '만', '하잖아', '아무래도', '사랑', '인가', '봐']"],
#        [34943312, '나의 X에게', '경서', '발라드',
#         '우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤이 새도록 네게 말할 거야 너를 좋아한다고 안녕 그대야 요즘 어떻게 지내 가로수길 걷다가 생각이 나서 행복해 보이는 사람들 속에 우리 둘만 없어서 어색했었어 늘 집에 갈 땐 항상 뒤돌아보면 날 보며 웃어주던 네가 생각났어 우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤이 새도록 네게 말할 거야 너를 좋아한다고 토요일마다 가던 한강공원에 이어폰 하나씩 나눠끼고서 벚꽃엔딩같이 듣고 있으면 부러울 게 없었어 너만 있으면 널 사랑할 때 내가 너무 그리워 날 보며 웃어주던 네가 보고 싶어 우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤이 새도록 네게 말할 거야 너를 좋아한다고 같이 별 보러 갈래 널 다시 만나면 네 옆에 기대서 잠들고 싶어 너의 품에 안길래 이 밤이 새도록 내 곁에 있어줘 내겐 너뿐이라고',
#         "['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추억', '들', '이', '너무', '그리워', '너', '의', '품', '에', '안길', '래', '이', '밤', '이', '새', '도록', '네', '게', '말', '할', '거야', '너', '를', '좋아한다고', '안녕', '그대', '야', '요즘', '어떻게', '지내', '가로수길', '걷다가', '생각', '이', '나서', '행복해', '보이는', '사람', '들', '속', '에', '우리', '둘', '만', '없어서', '어색했었어', '늘', '집', '에', '갈', '땐', '항상', '뒤', '돌아보면', '날', '보며', '웃어주던', '네', '가', '생각났어', '우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추억', '들', '이', '너무', '그리워', '너', '의', '품', '에', '안길', '래', '이', '밤', '이', '새', '도록', '네', '게', '말', '할', '거야', '너', '를', '좋아한다고', '토요일', '마다', '가던', '한강', '공원', '에', '이어폰', '하나', '씩', '나눠', '끼고서', '벚꽃', '엔딩', '같이', '듣고', '있으면', '부러울', '게', '없었어', '너', '만', '있으면', '널', '사랑', '할', '때', '내', '가', '너무', '그리워', '날', '보며', '웃어주던', '네', '가', '보고', '싶어', '우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추억', '들', '이', '너무', '그리워', '너', '의', '품', '에', '안길', '래', '이', '밤', '이', '새', '도록', '네', '게', '말', '할', '거야', '너', '를', '좋아한다고', '같이', '별', '보러', '갈래', '널', '다시', '만나면', '네', '옆', '에', '기대서', '잠들고', '싶어', '너', '의', '품', '에', '안길', '래', '이', '밤', '이', '새', '도록', '내', '곁', '에', '있어줘', '내겐', '너뿐이', '라고']"],
#        ...,
#        [33572058, '서투른 고백', '그_냥', '인디음악, 포크/블루스',
#         '보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이 어색할 수 있지만 오늘만큼은 너의 맘을 듣고 싶어 사실 너를 좋아한단 말이야 커져가는 마음 감출 수 없어서 널 내 품에 가득 안고 싶어 나 네가 좋아하는 나의 노래도 항상 너를 위해 부를게 그러니까 웃지만 말고 내 손을 잡아줘 조금은 알고 있었지 너 너무 티가 났었지 나 어쩔 수 없어 넌 항상 예뻤으니까 서투른 나의 고백이 어색할 수 있지만 오늘만큼은 너에게 말하고 싶어 사실 너를 좋아한단 말이야 커져가는 마음 감출 수 없어서 널 내 품에 가득 안고 싶어 나 네가 좋아하는 나의 노래도 항상 너를 위해 부를게 그러니까 웃지만 말고 내 손을 잡아줘 너를 많이 좋아해 이 바보야 나의 세상을 전부 다 네게 줄게 늘 지금처럼만 곁에 있어줘 네가 좋아하는 나의 노래도 항상 너를 위해 부를게 그러니까 웃지만 말고 지켜봐줘 서투른 고백이지만 세상 누구보다 행복하게 해줄게',
#         "['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나', '의', '마음', '을', '전하', '고', '싶어진거야', '서투른', '나', '의', '고백', '이', '어색할', '수', '있지만', '오늘', '만큼은', '너', '의', '맘', '을', '듣고', '싶어', '사실', '너', '를', '좋아한단', '말', '이야', '커져가는', '마음', '감출', '수', '없어서', '널', '내', '품', '에', '가득', '안고', '싶어', '나', '네', '가', '좋아하는', '나', '의', '노래', '도', '항상', '너', '를', '위해', '부를게', '그러니까', '웃', '지만', '말고', '내', '손', '을', '잡아줘', '조금', '은', '알', '고', '있었지', '너', '너무', '티', '가', '났었지', '나', '어쩔', '수', '없어', '넌', '항상', '예뻤으니까', '서투른', '나', '의', '고백', '이', '어색할', '수', '있지만', '오늘', '만큼은', '너', '에게', '말', '하고', '싶어', '사실', '너', '를', '좋아한단', '말', '이야', '커져가는', '마음', '감출', '수', '없어서', '널', '내', '품', '에', '가득', '안고', '싶어', '나', '네', '가', '좋아하는', '나', '의', '노래', '도', '항상', '너', '를', '위해', '부를게', '그러니까', '웃', '지만', '말고', '내', '손', '을', '잡아줘', '너', '를', '많이', '좋아해', '이', '바보', '야', '나', '의', '세상', '을', '전부', '다', '네', '게', '줄', '게', '늘', '지금', '처럼만', '곁', '에', '있어줘', '네', '가', '좋아하는', '나', '의', '노래', '도', '항상', '너', '를', '위해', '부를게', '그러니까', '웃', '지만', '말고', '지켜봐줘', '서투른', '고백', '이지만', '세상', '누구', '보다', '행복하게', '해줄게']"],
#        [32613630, '연가', '정우', '인디음악, 포크/블루스',
#         '이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝마 같은 당신을 붙입니다 떨어진 마음도 줍습니다 당신 좋은 사람이 아니래도 나 멋대로 실망하지 않아요 넝마 같은 우릴 여밉니다 벌어진 그 날을 붙입니다 네가 아프고 힘든 사람이래도 나는 곁에 앉아라 이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고',
#         "['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨', '에', '힘', '을', '풀', '고', '숨', '들이마시고', '눈', '감지', '말고', '넝마', '같은', '당신', '을', '붙입니다', '떨어진', '마음', '도', '줍습니다', '당신', '좋은', '사람', '이', '아니래도', '나', '멋대로', '실망하지', '않아요', '넝마', '같은', '우릴', '여', '밉니다', '벌어진', '그', '날', '을', '붙입니다', '네', '가', '아프고', '힘든', '사람', '이래도', '나', '는', '곁', '에', '앉아라', '이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨', '에', '힘', '을', '풀', '고', '숨', '들이마시고', '눈', '감지', '말고']"],
#        [33221082, '소등', '109', '인디음악, 포크/블루스',
#         '오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러보니 꽤 늦은 시간인데 여기저기 하나씩 불이 켜져 있는 게 보이네 나에게 말해줄래요 지금까지 숨겨왔던 것들을 고민과 걱정 담아서 그대 마음의 불을 꺼요 나의 말들이 위로가 될진 모르지만 네 옆에 있을게 기댈 곳 없이 혼자 걷지 말고 내 손을 잡고 같이 걷자 너의 두려움 모든 걸 알 순 없겠지만 네 옆에 있을게 조금씩 천천히 불빛에 담아서 눈을 감고 불을 끄고 잠에 들어요 나에게 말해줄래요 지금까지 잠 못 들게 했었던 고민과 걱정 담아서 그대 마음에 불을 꺼요 나의 말들이 위로가 될진 모르지만 네 옆에 있을게 기댈 곳 없이 혼자 걷지 말고 내 손을 잡고 같이 걷자 너의 두려움 모든 걸 알 순 없겠지만 네 옆에 있을게 조금씩 천천히 불빛에 담아서 눈을 감고 불을 끄고 잠에 들어요',
#         "['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리', '가', '아파와', '서', '잠시', '앉을', '곳', '을', '찾았어', '주변', '을', '둘러보니', '꽤', '늦은', '시간', '인데', '여기저기', '하나', '씩', '불', '이', '켜져', '있는', '게', '보이', '네', '나', '에게', '말', '해줄래요', '지금', '까지', '숨겨', '왔던', '것', '들', '을', '고민', '과', '걱정', '담아서', '그대', '마음', '의', '불', '을', '꺼요', '나', '의', '말', '들', '이', '위로', '가', '될진', '모르지만', '네', '옆', '에', '있을게', '기댈', '곳', '없이', '혼자', '걷지', '말고', '내', '손', '을', '잡고', '같이', '걷자', '너', '의', '두려움', '모든', '걸', '알', '순', '없겠지만', '네', '옆', '에', '있을게', '조금씩', '천천히', '불빛', '에', '담아서', '눈', '을', '감고', '불', '을', '끄고', '잠', '에', '들어요', '나', '에게', '말', '해줄래요', '지금', '까지', '잠', '못', '들게', '했었던', '고민', '과', '걱정', '담아서', '그대', '마음', '에', '불', '을', '꺼요', '나', '의', '말', '들', '이', '위로', '가', '될진', '모르지만', '네', '옆', '에', '있을게', '기댈', '곳', '없이', '혼자', '걷지', '말고', '내', '손', '을', '잡고', '같이', '걷자', '너', '의', '두려움', '모든', '걸', '알', '순', '없겠지만', '네', '옆', '에', '있을게', '조금씩', '천천히', '불빛', '에', '담아서', '눈', '을', '감고', '불', '을', '끄고', '잠', '에', '들어요']"]],
#       dtype=object)

# %%
summaries = []
for music in music_list.values:
    summary = music[1]
    summary += music[2]
    summary += music[3]
    summary += music[4]
    summaries.append(summary)
music_list['제목_가수_장르_가사'] = summaries

music_list
# Out:
#       melon_music_code                     제목            가수            장르  \
# 0             35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)           발라드
# 1             34657844                 사랑인가 봐          멜로망스    발라드, 국내드라마
# 2             34943312                 나의 X에게            경서           발라드
# 3             34787226                내가 아니라도            주호           발라드
# 4             34061322              사랑은 늘 도망가           임영웅    발라드, 국내드라마
# ...                ...                    ...           ...           ...
# 6521          33151943  paranoid (Feat. DEAN)         Mokyo        포크/블루스
# 6522          33509132   꿈 (Still I Love You)           김수영  인디음악, 포크/블루스
# 6523          33572058                 서투른 고백           그_냥  인디음악, 포크/블루스
# 6524          32613630                     연가            정우  인디음악, 포크/블루스
# 6525          33221082                     소등           109  인디음악, 포크/블루스
#
#                                                      가사  \
# 0     잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1     너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3     사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...                                                 ...
# 6521  So I got paranoid with the drums I ain’t got t...
# 6522  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징  \
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
#                                             제목_가수_장르_가사
# 0     그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1     사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
# [6526 rows x 7 columns]

# %%
import re

# %%
music_list['기호제거'] = [re.sub('[^A-Za-z0-9가-힣]', '', s) for s in music_list['제목_가수_장르_가사']]

# %%
music_list['기호제거'] = music_list['제목_가수_장르_가사'].str.replace("[^A-Za-z0-9가-힣 ]", " ")
music_list
# Out:
# /var/folders/b5/__960gvn4nd3bhxr41c7x3fw0000gn/T/ipykernel_28696/2693673119.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   music_list['기호제거'] = music_list['제목_가수_장르_가사'].str.replace("[^A-Za-z0-9가-힣 ]", " ")
#       melon_music_code                     제목            가수            장르  \
# 0             35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)           발라드
# 1             34657844                 사랑인가 봐          멜로망스    발라드, 국내드라마
# 2             34943312                 나의 X에게            경서           발라드
# 3             34787226                내가 아니라도            주호           발라드
# 4             34061322              사랑은 늘 도망가           임영웅    발라드, 국내드라마
# ...                ...                    ...           ...           ...
# 6521          33151943  paranoid (Feat. DEAN)         Mokyo        포크/블루스
# 6522          33509132   꿈 (Still I Love You)           김수영  인디음악, 포크/블루스
# 6523          33572058                 서투른 고백           그_냥  인디음악, 포크/블루스
# 6524          32613630                     연가            정우  인디음악, 포크/블루스
# 6525          33221082                     소등           109  인디음악, 포크/블루스
#
#                                                      가사  \
# 0     잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1     너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3     사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...                                                 ...
# 6521  So I got paranoid with the drums I ain’t got t...
# 6522  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징  \
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
#                                             제목_가수_장르_가사  \
# 0     그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1     사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                    기호제거
# 0     그때 그 순간 그대로  그그그 WSG워너비  가야G 발라드잘 지냈지  조금은 어색해...
# 1     사랑인가 봐멜로망스발라드  국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드  국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid  Feat  DEAN Mokyo포크 블루스So I got paran...
# 6522  꿈  Still I Love You 김수영인디음악  포크 블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그 냥인디음악  포크 블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악  포크 블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악  포크 블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
# [6526 rows x 8 columns]

# %%
music_list
# Out:
#       melon_music_code                     제목            가수            장르  \
# 0             35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)           발라드
# 1             34657844                 사랑인가 봐          멜로망스    발라드, 국내드라마
# 2             34943312                 나의 X에게            경서           발라드
# 3             34787226                내가 아니라도            주호           발라드
# 4             34061322              사랑은 늘 도망가           임영웅    발라드, 국내드라마
# ...                ...                    ...           ...           ...
# 6521          33151943  paranoid (Feat. DEAN)         Mokyo        포크/블루스
# 6522          33509132   꿈 (Still I Love You)           김수영  인디음악, 포크/블루스
# 6523          33572058                 서투른 고백           그_냥  인디음악, 포크/블루스
# 6524          32613630                     연가            정우  인디음악, 포크/블루스
# 6525          33221082                     소등           109  인디음악, 포크/블루스
#
#                                                      가사  \
# 0     잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1     너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3     사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...                                                 ...
# 6521  So I got paranoid with the drums I ain’t got t...
# 6522  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징  \
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
#                                             제목_가수_장르_가사  \
# 0     그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1     사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                    기호제거
# 0     그때그순간그대로그그그WSG워너비가야G발라드잘지냈지조금은어색해요즘좋아보여인사나누며사실...
# 1     사랑인가봐멜로망스발라드국내드라마너와함께하고싶은일들을상상하는게요즘내일상이되고너의즐거워...
# 2     나의X에게경서발라드우리다시만날래예쁘게빛나던모든추억들이너무그리워너의품에안길래이밤이새도...
# 3     내가아니라도주호발라드사랑이었다별거없던내하루에빛이돼준단한사람나보다나를더아껴주던너를그땐...
# 4     사랑은늘도망가임영웅발라드국내드라마눈물이난다이길을걸으면그사람손길이자꾸생각이난다붙잡지못...
# ...                                                 ...
# 6521  paranoidFeatDEANMokyo포크블루스SoIgotparanoidwithth...
# 6522  꿈StillILoveYou김수영인디음악포크블루스어젯밤에불안했던무서웠던꿈을꾸고너에게달...
# 6523  서투른고백그냥인디음악포크블루스보랏빛하늘에문득생각이들었어나의마음을전하고싶어진거야서투른...
# 6524  연가정우인디음악포크블루스이제널안고그무렵을내려놓고어깨에힘을풀고숨들이마시고눈감지말고넝마...
# 6525  소등109인디음악포크블루스오늘도어김없이집에가는언덕다리가아파와서잠시앉을곳을찾았어주변을...
#
# [6526 rows x 8 columns]

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
music_list['종합 토크나이징'] = music_list['기호제거'].apply(okt.morphs)
music_list
# Out:
#       melon_music_code                     제목            가수            장르  \
# 0             35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)           발라드
# 1             34657844                 사랑인가 봐          멜로망스    발라드, 국내드라마
# 2             34943312                 나의 X에게            경서           발라드
# 3             34787226                내가 아니라도            주호           발라드
# 4             34061322              사랑은 늘 도망가           임영웅    발라드, 국내드라마
# ...                ...                    ...           ...           ...
# 6521          33151943  paranoid (Feat. DEAN)         Mokyo        포크/블루스
# 6522          33509132   꿈 (Still I Love You)           김수영  인디음악, 포크/블루스
# 6523          33572058                 서투른 고백           그_냥  인디음악, 포크/블루스
# 6524          32613630                     연가            정우  인디음악, 포크/블루스
# 6525          33221082                     소등           109  인디음악, 포크/블루스
#
#                                                      가사  \
# 0     잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1     너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3     사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...                                                 ...
# 6521  So I got paranoid with the drums I ain’t got t...
# 6522  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징  \
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
#                                             제목_가수_장르_가사  \
# 0     그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1     사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                    기호제거  \
# 0     그때 그 순간 그대로  그그그 WSG워너비  가야G 발라드잘 지냈지  조금은 어색해...
# 1     사랑인가 봐멜로망스발라드  국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드  국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid  Feat  DEAN Mokyo포크 블루스So I got paran...
# 6522  꿈  Still I Love You 김수영인디음악  포크 블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그 냥인디음악  포크 블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악  포크 블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악  포크 블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                종합 토크나이징
# 0     [그때, 그, 순간, 그대로, 그, 그, 그, WSG, 워, 너비, 가야, G, 발...
# 1     [사랑, 인가, 봐, 멜, 로망스, 발라드, 국내, 드라마, 너, 와, 함께, 하고...
# 2     [나, 의, X, 에게, 경, 서, 발라드, 우리, 다시, 만날, 래, 예쁘게, 빛...
# 3     [내, 가, 아니라도, 주호, 발라드, 사랑, 이었다, 별거, 없던, 내, 하루, ...
# 4     [사랑, 은, 늘, 도망가, 임영웅, 발라드, 국내, 드라마, 눈물, 이, 난다, ...
# ...                                                 ...
# 6521  [paranoid, Feat, DEAN, Mokyo, 포크, 블루스, So, I, ...
# 6522  [꿈, Still, I, Love, You, 김수영, 인디음악, 포크, 블루스, 어...
# 6523  [서투른, 고백, 그, 냥, 인디음악, 포크, 블루스, 보랏빛, 하늘, 에, 문득,...
# 6524  [연, 가정우, 인디음악, 포크, 블루스, 이제, 널, 안고, 그, 무렵, 을, 내...
# 6525  [소등, 109, 인디음악, 포크, 블루스, 오늘, 도, 어김없이, 집, 에, 가는...
#
# [6526 rows x 9 columns]

# %%
music_list.to_csv('music_add.csv')

# %%
music_df = pd.read_csv('music_add.csv')

# %%
music_df
# Out:
#       Unnamed: 0  melon_music_code                     제목            가수  \
# 0              0          35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)
# 1              1          34657844                 사랑인가 봐          멜로망스
# 2              2          34943312                 나의 X에게            경서
# 3              3          34787226                내가 아니라도            주호
# 4              4          34061322              사랑은 늘 도망가           임영웅
# ...          ...               ...                    ...           ...
# 6521        6521          33151943  paranoid (Feat. DEAN)         Mokyo
# 6522        6522          33509132   꿈 (Still I Love You)           김수영
# 6523        6523          33572058                 서투른 고백           그_냥
# 6524        6524          32613630                     연가            정우
# 6525        6525          33221082                     소등           109
#
#                 장르                                                 가사  \
# 0              발라드  잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1       발라드, 국내드라마  너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2              발라드  우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3              발라드  사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4       발라드, 국내드라마  눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...            ...                                                ...
# 6521        포크/블루스  So I got paranoid with the drums I ain’t got t...
# 6522  인디음악, 포크/블루스  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  인디음악, 포크/블루스  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  인디음악, 포크/블루스  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  인디음악, 포크/블루스  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징  \
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
#                                             제목_가수_장르_가사  \
# 0     그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1     사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                    기호제거  \
# 0     그때 그 순간 그대로  그그그 WSG워너비  가야G 발라드잘 지냈지  조금은 어색해...
# 1     사랑인가 봐멜로망스발라드  국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드  국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid  Feat  DEAN Mokyo포크 블루스So I got paran...
# 6522  꿈  Still I Love You 김수영인디음악  포크 블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그 냥인디음악  포크 블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악  포크 블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악  포크 블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                종합 토크나이징
# 0     ['그때', '그', '순간', '그대로', '그', '그', '그', 'WSG',...
# 1     ['사랑', '인가', '봐', '멜', '로망스', '발라드', '국내', '드라...
# 2     ['나', '의', 'X', '에게', '경', '서', '발라드', '우리', '...
# 3     ['내', '가', '아니라도', '주호', '발라드', '사랑', '이었다', '...
# 4     ['사랑', '은', '늘', '도망가', '임영웅', '발라드', '국내', '드...
# ...                                                 ...
# 6521  ['paranoid', 'Feat', 'DEAN', 'Mokyo', '포크', '블...
# 6522  ['꿈', 'Still', 'I', 'Love', 'You', '김수영', '인디음...
# 6523  ['서투른', '고백', '그', '냥', '인디음악', '포크', '블루스', '...
# 6524  ['연', '가정우', '인디음악', '포크', '블루스', '이제', '널', '...
# 6525  ['소등', '109', '인디음악', '포크', '블루스', '오늘', '도', ...
#
# [6526 rows x 10 columns]

# %%
music_df.rename(columns={"Unnamed: 0":'id'}, inplace=True)
music_df
# Out:
#         id  melon_music_code                     제목            가수  \
# 0        0          35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)
# 1        1          34657844                 사랑인가 봐          멜로망스
# 2        2          34943312                 나의 X에게            경서
# 3        3          34787226                내가 아니라도            주호
# 4        4          34061322              사랑은 늘 도망가           임영웅
# ...    ...               ...                    ...           ...
# 6521  6521          33151943  paranoid (Feat. DEAN)         Mokyo
# 6522  6522          33509132   꿈 (Still I Love You)           김수영
# 6523  6523          33572058                 서투른 고백           그_냥
# 6524  6524          32613630                     연가            정우
# 6525  6525          33221082                     소등           109
#
#                 장르                                                 가사  \
# 0              발라드  잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1       발라드, 국내드라마  너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2              발라드  우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3              발라드  사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4       발라드, 국내드라마  눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...            ...                                                ...
# 6521        포크/블루스  So I got paranoid with the drums I ain’t got t...
# 6522  인디음악, 포크/블루스  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  인디음악, 포크/블루스  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  인디음악, 포크/블루스  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  인디음악, 포크/블루스  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
#                                                   토크나이징  \
# 0     ['잘', '지냈지', '?', '조금', '은', '어색해', '요즘', '좋아'...
# 1     ['너', '와', '함께', '하고', '싶은', '일', '들', '을', '상...
# 2     ['우리', '다시', '만날', '래', '예쁘게', '빛나던', '모든', '추...
# 3     ['사랑', '이었다', '별거', '없던', '내', '하루', '에', '빛',...
# 4     ['눈물', '이', '난다', '이', '길', '을', '걸으면', '그', '...
# ...                                                 ...
# 6521  ['So', 'I', 'got', 'paranoid', 'with', 'the', ...
# 6522  ['어젯밤', '에', '불안했던', '무서웠던', '꿈', '을', '꾸고', '...
# 6523  ['보랏빛', '하늘', '에', '문득', '생각', '이', '들었어', '나'...
# 6524  ['이제', '널', '안고', '그', '무렵', '을', '내려놓고', '어깨'...
# 6525  ['오늘', '도', '어김없이', '집', '에', '가는', '언덕', '다리'...
#
#                                             제목_가수_장르_가사  \
# 0     그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1     사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                    기호제거  \
# 0     그때 그 순간 그대로  그그그 WSG워너비  가야G 발라드잘 지냈지  조금은 어색해...
# 1     사랑인가 봐멜로망스발라드  국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2     나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3     내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4     사랑은 늘 도망가임영웅발라드  국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...                                                 ...
# 6521  paranoid  Feat  DEAN Mokyo포크 블루스So I got paran...
# 6522  꿈  Still I Love You 김수영인디음악  포크 블루스어젯밤에 불안했던 무...
# 6523  서투른 고백그 냥인디음악  포크 블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  연가정우인디음악  포크 블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  소등109인디음악  포크 블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
#                                                종합 토크나이징
# 0     ['그때', '그', '순간', '그대로', '그', '그', '그', 'WSG',...
# 1     ['사랑', '인가', '봐', '멜', '로망스', '발라드', '국내', '드라...
# 2     ['나', '의', 'X', '에게', '경', '서', '발라드', '우리', '...
# 3     ['내', '가', '아니라도', '주호', '발라드', '사랑', '이었다', '...
# 4     ['사랑', '은', '늘', '도망가', '임영웅', '발라드', '국내', '드...
# ...                                                 ...
# 6521  ['paranoid', 'Feat', 'DEAN', 'Mokyo', '포크', '블...
# 6522  ['꿈', 'Still', 'I', 'Love', 'You', '김수영', '인디음...
# 6523  ['서투른', '고백', '그', '냥', '인디음악', '포크', '블루스', '...
# 6524  ['연', '가정우', '인디음악', '포크', '블루스', '이제', '널', '...
# 6525  ['소등', '109', '인디음악', '포크', '블루스', '오늘', '도', ...
#
# [6526 rows x 10 columns]

# %%
music_df = music_df[['id', '종합 토크나이징']]
music_df
# Out:
#         id                                           종합 토크나이징
# 0        0  ['그때', '그', '순간', '그대로', '그', '그', '그', 'WSG',...
# 1        1  ['사랑', '인가', '봐', '멜', '로망스', '발라드', '국내', '드라...
# 2        2  ['나', '의', 'X', '에게', '경', '서', '발라드', '우리', '...
# 3        3  ['내', '가', '아니라도', '주호', '발라드', '사랑', '이었다', '...
# 4        4  ['사랑', '은', '늘', '도망가', '임영웅', '발라드', '국내', '드...
# ...    ...                                                ...
# 6521  6521  ['paranoid', 'Feat', 'DEAN', 'Mokyo', '포크', '블...
# 6522  6522  ['꿈', 'Still', 'I', 'Love', 'You', '김수영', '인디음...
# 6523  6523  ['서투른', '고백', '그', '냥', '인디음악', '포크', '블루스', '...
# 6524  6524  ['연', '가정우', '인디음악', '포크', '블루스', '이제', '널', '...
# 6525  6525  ['소등', '109', '인디음악', '포크', '블루스', '오늘', '도', ...
#
# [6526 rows x 2 columns]

# %%
music_df.to_csv('music_summary.csv')

# %%
book_list = pd.read_csv('data/book_list.csv')
book_list
# Out:
#      Unnamed: 0  user_id  book_id  status                 review  rate  \
# 0             0        1     1518       0                    NaN   NaN
# 1             1        1     6310       0                    NaN   NaN
# 2             2        1     6469       1  사후세계에 대한 상상은 언제나 흥미롭다  10.0
# 3             3        1     6614       0                    NaN   NaN
# 4             4        1     6615       0                    NaN   NaN
# ..          ...      ...      ...     ...                    ...   ...
# 121         121       18     2848       0                    NaN   NaN
# 122         122       18     9395       0                    NaN   NaN
# 123         123       20    48125       0                    NaN   NaN
# 124         124       20    55456       0                    NaN   NaN
# 125         125       20    63116       0                    NaN   NaN
#
#      created_dt modified_dt
# 0    2022-08-27         NaN
# 1    2022-08-15         NaN
# 2    2022-08-16         NaN
# 3    2022-08-16         NaN
# 4    2022-08-16         NaN
# ..          ...         ...
# 121  2022-08-16         NaN
# 122  2022-08-16         NaN
# 123  2022-08-17         NaN
# 124  2022-08-17         NaN
# 125  2022-08-17         NaN
#
# [126 rows x 8 columns]

# %%
book_list.drop(['Unnamed: 0', 'review', 'rate', 'created_dt', 'modified_dt'], inplace=True, axis=1)
book_list
# Out:
#      user_id  book_id  status
# 0          1     1518       0
# 1          1     6310       0
# 2          1     6469       1
# 3          1     6614       0
# 4          1     6615       0
# ..       ...      ...     ...
# 121       18     2848       0
# 122       18     9395       0
# 123       20    48125       0
# 124       20    55456       0
# 125       20    63116       0
#
# [126 rows x 3 columns]

# %%
books = pd.read_csv('data/books.csv')
books.drop(['Unnamed: 0', 'sense'], inplace=True, axis=1)
books.fillna('', inplace=True)
summaries = []
for book in books.values:
    summary = book[1]
    summary += book[2]
    summary += book[3]
    summary += book[4]
    summary += book[5]
    summaries.append(summary)
books['summary'] = summaries
books
# Out:
#           id                                              title  \
# 0          1                             리스트 고독한가운데 신의 축복 (984)
# 1          2                                 거짓말이다 + 꽃다발 상품권 세트
# 2          3              [헌금봉투] 주일헌금 201 (1속50매) - VJ-1311-201
# 3          4              [헌금봉투] 주일헌금 202 (1속50매) - VJ-1311-202
# 4          5  엘르 Elle E형 2022.8 (표지 : NCT 재현) (부록없음) - 주요기사 ...
# ...      ...                                                ...
# 77509  79422                    희망을 부르는 어린이 2022.가을 - 어린이 인문교양지
# 77510  79423                            상담 및 심리교육 프로그램 개발 - 제2판
# 77511  79424                              조각, 너에게 주고 싶은 나의 한 조각
# 77512  79425                                             삼봉파 선도
# 77513  79476             페이스북 광고 & 타겟마케팅 - 하루 5000원으로 10만명 도달하기
#
#                                             author               publisher  \
# 0                                 마스트미디어 편집부 (지은이)                  마스트미디어
# 1                                        김탁환 (지은이)                    북스피어
# 2                                    비전북 편집부 (지은이)         비전북(VisionBook)
# 3                                    비전북 편집부 (지은이)         비전북(VisionBook)
# 4                                  허스트중앙 편집부 (지은이)  허스트중앙(Hearst-Joongang)
# ...                                            ...                     ...
# 77509                                 인디고 서원 (지은이)                   인디고서원
# 77510                                    김창대 (지은이)                     학지사
# 77511  이세설, 권형준, 해운, 공윤경, 김경아, 황윤이, 임제리, 정소이 (지은이)                    글ego
# 77512                               채성훈, 김대훈 (지은이)                    다크아트
# 77513                                페꼼마 이종근 (지은이)                   리텍콘텐츠
#
#                                                  summary      genre
# 0      리스트 고독한가운데 신의 축복 (984)마스트미디어 편집부 (지은이)마스트미디어예술...    예술/대중문화
# 1      거짓말이다 + 꽃다발 상품권 세트김탁환 (지은이)북스피어김탁환 작가의 &lt;거짓말...    소설/시/희곡
# 2      [헌금봉투] 주일헌금 201 (1속50매) - VJ-1311-201비전북 편집부 (...      종교/역학
# 3      [헌금봉투] 주일헌금 202 (1속50매) - VJ-1311-202비전북 편집부 (...      종교/역학
# 4      엘르 Elle E형 2022.8 (표지 : NCT 재현) (부록없음) - 주요기사 ...         잡지
# ...                                                  ...        ...
# 77509  희망을 부르는 어린이 2022.가을 - 어린이 인문교양지인디고 서원 (지은이)인디고...        어린이
# 77510       상담 및 심리교육 프로그램 개발 - 제2판김창대 (지은이)학지사대학교재/전문서적  대학교재/전문서적
# 77511  조각, 너에게 주고 싶은 나의 한 조각이세설, 권형준, 해운, 공윤경, 김경아, 황...        어린이
# 77512  삼봉파 선도채성훈, 김대훈 (지은이)다크아트'삼봉파' 선도는 인간이 가진 근원적인 ...        인문학
# 77513  페이스북 광고 & 타겟마케팅 - 하루 5000원으로 10만명 도달하기페꼼마 이종근 ...       경제경영
#
# [77514 rows x 6 columns]

# %%
books.drop(['title', 'author', 'publisher', 'genre'], axis=1, inplace=True)

# %%
books
# Out:
#           id                                            summary
# 0          1  리스트 고독한가운데 신의 축복 (984)마스트미디어 편집부 (지은이)마스트미디어예술...
# 1          2  거짓말이다 + 꽃다발 상품권 세트김탁환 (지은이)북스피어김탁환 작가의 &lt;거짓말...
# 2          3  [헌금봉투] 주일헌금 201 (1속50매) - VJ-1311-201비전북 편집부 (...
# 3          4  [헌금봉투] 주일헌금 202 (1속50매) - VJ-1311-202비전북 편집부 (...
# 4          5  엘르 Elle E형 2022.8 (표지 : NCT 재현) (부록없음) - 주요기사 ...
# ...      ...                                                ...
# 77509  79422  희망을 부르는 어린이 2022.가을 - 어린이 인문교양지인디고 서원 (지은이)인디고...
# 77510  79423       상담 및 심리교육 프로그램 개발 - 제2판김창대 (지은이)학지사대학교재/전문서적
# 77511  79424  조각, 너에게 주고 싶은 나의 한 조각이세설, 권형준, 해운, 공윤경, 김경아, 황...
# 77512  79425  삼봉파 선도채성훈, 김대훈 (지은이)다크아트'삼봉파' 선도는 인간이 가진 근원적인 ...
# 77513  79476  페이스북 광고 & 타겟마케팅 - 하루 5000원으로 10만명 도달하기페꼼마 이종근 ...
#
# [77514 rows x 2 columns]

# %%
from konlpy.tag import Mecab
from tqdm import tqdm

# %%
# 불용어 가져오기
stopwords = []
with open("data/hangul_stopword.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        line = line.strip()  # 줄 끝의 줄 바꿈 문자를 제거한다.
        line = line.replace('\n', '')
        stopwords.append(line)

# %%
books['summary'] = books['summary'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "")
books
# Out:
# /var/folders/b5/__960gvn4nd3bhxr41c7x3fw0000gn/T/ipykernel_28696/2444524825.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   books['summary'] = books['summary'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "")
#           id                                            summary
# 0          1        리스트 고독한가운데 신의 축복 마스트미디어 편집부 지은이마스트미디어예술대중문화
# 1          2  거짓말이다  꽃다발 상품권 세트김탁환 지은이북스피어김탁환 작가의 거짓말이다와 꽃다발...
# 2          3  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 3          4  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 4          5  엘르  형  표지   재현 부록없음  주요기사   재현 김태리 여자아이들 민니 르세...
# ...      ...                                                ...
# 77509  79422        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 77510  79423            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 77511  79424  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 77512  79425  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 77513  79476  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [77514 rows x 2 columns]

# %%
mecab = Mecab()
corpus_list = []

# %%
for index, row in tqdm(books.iterrows(), total=len(books)):
    text = row['summary']
    tokenized_sentence = okt.morphs(text)
    stopwords_removed_sentence = [
        word for word in tokenized_sentence if not word in stopwords]  # 불용어 제거
    corpus_list.append(stopwords_removed_sentence)
books['summary'] = corpus_list
# Out:
# 100%|██████████| 77514/77514 [14:20<00:00, 90.09it/s]

# %%
books
# Out:
#           id                                            summary
# 0          1  [리스트, 고독, 한가운데, 신의, 축복, 마스트, 미디어, 편집, 부, 지은이, ...
# 1          2  [거짓말, 이다, 꽃다발, 상품권, 세트, 김탁환, 지은, 이북, 스피어, 김탁환,...
# 2          3  [헌금, 봉투, 주일, 헌금, 매, 비, 전북, 편집, 부, 지은, 이비, 전북, ...
# 3          4  [헌금, 봉투, 주일, 헌금, 매, 비, 전북, 편집, 부, 지은, 이비, 전북, ...
# 4          5  [엘르, 형, 표지, 재현, 부록, 없음, 주요, 기사, 재현, 김태리, 여자아이,...
# ...      ...                                                ...
# 77509  79422  [희망, 을, 부르는, 어린이, 가을, 어린이, 인문, 교양, 인디고, 서원, 지은...
# 77510  79423  [상담, 및, 심리, 교육, 프로그램, 개발, 제판, 김창, 대, 지은, 이학, 사...
# 77511  79424  [조각, 너, 에게, 주고, 싶은, 의, 조각, 이세, 설, 권형준, 해운, 공, ...
# 77512  79425  [삼봉, 파, 선도, 채성훈, 김대훈, 지은이, 다크, 아트, 삼봉, 파, 선도, ...
# 77513  79476  [페이스북, 광고, 타겟, 마케팅, 하루, 으로, 만, 도달, 하기, 페꼼, 마, ...
#
# [77514 rows x 2 columns]

# %%
books.to_csv('book_summary.csv')

# %%
for i in range(6526,6530):
    print(i)
# Out:
# 6526
# 6527
# 6528
# 6529

# %%
id_list = []
for i in range(6526,84040):
    id_list.append(i)
books['id'] = id_list

# %%
books
# Out:
#           id                                            summary
# 0       6526  [리스트, 고독, 한가운데, 신의, 축복, 마스트, 미디어, 편집, 부, 지은이, ...
# 1       6527  [거짓말, 이다, 꽃다발, 상품권, 세트, 김탁환, 지은, 이북, 스피어, 김탁환,...
# 2       6528  [헌금, 봉투, 주일, 헌금, 매, 비, 전북, 편집, 부, 지은, 이비, 전북, ...
# 3       6529  [헌금, 봉투, 주일, 헌금, 매, 비, 전북, 편집, 부, 지은, 이비, 전북, ...
# 4       6530  [엘르, 형, 표지, 재현, 부록, 없음, 주요, 기사, 재현, 김태리, 여자아이,...
# ...      ...                                                ...
# 77509  84035  [희망, 을, 부르는, 어린이, 가을, 어린이, 인문, 교양, 인디고, 서원, 지은...
# 77510  84036  [상담, 및, 심리, 교육, 프로그램, 개발, 제판, 김창, 대, 지은, 이학, 사...
# 77511  84037  [조각, 너, 에게, 주고, 싶은, 의, 조각, 이세, 설, 권형준, 해운, 공, ...
# 77512  84038  [삼봉, 파, 선도, 채성훈, 김대훈, 지은이, 다크, 아트, 삼봉, 파, 선도, ...
# 77513  84039  [페이스북, 광고, 타겟, 마케팅, 하루, 으로, 만, 도달, 하기, 페꼼, 마, ...
#
# [77514 rows x 2 columns]

# %%
books.to_csv('book_summary_renewal.csv')

# %%
music_df.rename(columns={"종합 토크나이징":'summary'}, inplace=True)
music_df
# Out:
# /var/folders/b5/__960gvn4nd3bhxr41c7x3fw0000gn/T/ipykernel_28696/1990083658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   music_df.rename(columns={"종합 토크나이징":'summary'}, inplace=True)
#         id                                            summary
# 0        0  ['그때', '그', '순간', '그대로', '그', '그', '그', 'WSG',...
# 1        1  ['사랑', '인가', '봐', '멜', '로망스', '발라드', '국내', '드라...
# 2        2  ['나', '의', 'X', '에게', '경', '서', '발라드', '우리', '...
# 3        3  ['내', '가', '아니라도', '주호', '발라드', '사랑', '이었다', '...
# 4        4  ['사랑', '은', '늘', '도망가', '임영웅', '발라드', '국내', '드...
# ...    ...                                                ...
# 6521  6521  ['paranoid', 'Feat', 'DEAN', 'Mokyo', '포크', '블...
# 6522  6522  ['꿈', 'Still', 'I', 'Love', 'You', '김수영', '인디음...
# 6523  6523  ['서투른', '고백', '그', '냥', '인디음악', '포크', '블루스', '...
# 6524  6524  ['연', '가정우', '인디음악', '포크', '블루스', '이제', '널', '...
# 6525  6525  ['소등', '109', '인디음악', '포크', '블루스', '오늘', '도', ...
#
# [6526 rows x 2 columns]

# %%
concat_df = pd.concat([music_df, books])
concat_df
# Out:
#           id                                            summary
# 0          0  ['그때', '그', '순간', '그대로', '그', '그', '그', 'WSG',...
# 1          1  ['사랑', '인가', '봐', '멜', '로망스', '발라드', '국내', '드라...
# 2          2  ['나', '의', 'X', '에게', '경', '서', '발라드', '우리', '...
# 3          3  ['내', '가', '아니라도', '주호', '발라드', '사랑', '이었다', '...
# 4          4  ['사랑', '은', '늘', '도망가', '임영웅', '발라드', '국내', '드...
# ...      ...                                                ...
# 77509  84035  [희망, 을, 부르는, 어린이, 가을, 어린이, 인문, 교양, 인디고, 서원, 지은...
# 77510  84036  [상담, 및, 심리, 교육, 프로그램, 개발, 제판, 김창, 대, 지은, 이학, 사...
# 77511  84037  [조각, 너, 에게, 주고, 싶은, 의, 조각, 이세, 설, 권형준, 해운, 공, ...
# 77512  84038  [삼봉, 파, 선도, 채성훈, 김대훈, 지은이, 다크, 아트, 삼봉, 파, 선도, ...
# 77513  84039  [페이스북, 광고, 타겟, 마케팅, 하루, 으로, 만, 도달, 하기, 페꼼, 마, ...
#
# [84040 rows x 2 columns]

# %%
concat_df.reset_index(inplace=True)

# %%
concat_df = concat_df.reset_index(inplace=True)
concat_df

# %%
concat_df
# Out:
#        index     id                                            summary
# 0          0      0  ['그때', '그', '순간', '그대로', '그', '그', '그', 'WSG',...
# 1          1      1  ['사랑', '인가', '봐', '멜', '로망스', '발라드', '국내', '드라...
# 2          2      2  ['나', '의', 'X', '에게', '경', '서', '발라드', '우리', '...
# 3          3      3  ['내', '가', '아니라도', '주호', '발라드', '사랑', '이었다', '...
# 4          4      4  ['사랑', '은', '늘', '도망가', '임영웅', '발라드', '국내', '드...
# ...      ...    ...                                                ...
# 84035  77509  84035  [희망, 을, 부르는, 어린이, 가을, 어린이, 인문, 교양, 인디고, 서원, 지은...
# 84036  77510  84036  [상담, 및, 심리, 교육, 프로그램, 개발, 제판, 김창, 대, 지은, 이학, 사...
# 84037  77511  84037  [조각, 너, 에게, 주고, 싶은, 의, 조각, 이세, 설, 권형준, 해운, 공, ...
# 84038  77512  84038  [삼봉, 파, 선도, 채성훈, 김대훈, 지은이, 다크, 아트, 삼봉, 파, 선도, ...
# 84039  77513  84039  [페이스북, 광고, 타겟, 마케팅, 하루, 으로, 만, 도달, 하기, 페꼼, 마, ...
#
# [84040 rows x 3 columns]

# %%
concat_df.drop(['index'], inplace=True, axis=1)

# %%
concat_df
# Out:
#           id                                            summary
# 0          0  ['그때', '그', '순간', '그대로', '그', '그', '그', 'WSG',...
# 1          1  ['사랑', '인가', '봐', '멜', '로망스', '발라드', '국내', '드라...
# 2          2  ['나', '의', 'X', '에게', '경', '서', '발라드', '우리', '...
# 3          3  ['내', '가', '아니라도', '주호', '발라드', '사랑', '이었다', '...
# 4          4  ['사랑', '은', '늘', '도망가', '임영웅', '발라드', '국내', '드...
# ...      ...                                                ...
# 84035  84035  [희망, 을, 부르는, 어린이, 가을, 어린이, 인문, 교양, 인디고, 서원, 지은...
# 84036  84036  [상담, 및, 심리, 교육, 프로그램, 개발, 제판, 김창, 대, 지은, 이학, 사...
# 84037  84037  [조각, 너, 에게, 주고, 싶은, 의, 조각, 이세, 설, 권형준, 해운, 공, ...
# 84038  84038  [삼봉, 파, 선도, 채성훈, 김대훈, 지은이, 다크, 아트, 삼봉, 파, 선도, ...
# 84039  84039  [페이스북, 광고, 타겟, 마케팅, 하루, 으로, 만, 도달, 하기, 페꼼, 마, ...
#
# [84040 rows x 2 columns]

# %%
concat_df.to_csv('concat.csv')

# %%
doc_df = concat_df[['id','summary']].values.tolist()

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
tagged_data = [TaggedDocument(words=_d, tags=[id]) for id, _d in doc_df]

# %%
max_epochs = 1000
model = Doc2Vec(vector_size=20,
                alpha=0.025,
                min_alpha=0.00025,
                min_count=1,
                dm=1)


model.build_vocab(tagged_data)

# 학습
for epoch in range(max_epochs):
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha
# Out:
# /var/folders/b5/__960gvn4nd3bhxr41c7x3fw0000gn/T/ipykernel_28696/1496567277.py:15: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   epochs=model.iter)

# %%
model.save('concat_model.h5')

# %%
concat_df[concat_df['id'] == 13043]

# %%
return_docs = model.docvecs.most_similar(13043, topn=10, restrict_vocab=6526)
return_docs

# %%
word2vec_model = Word2Vec.load('/Users/baaam771/Desktop/code/model/ko/ko.bin')
