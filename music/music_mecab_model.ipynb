# %%
import pandas as pd

# %%
music_df = pd.read_csv('/Users/baaam771/Desktop/code/model/music_del_stopword.csv')
music_df
# Out:
#       Unnamed: 0    id                                        제목_가수_장르_가사
# 0              0     0  그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1              1     1  사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2              2     2  나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3              3     3  내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4              4     4  사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...          ...   ...                                                ...
# 6521        6521  6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522        6522  6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523        6523  6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524        6524  6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525        6525  6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
# [6526 rows x 3 columns]

# %%
music_df.drop(['Unnamed: 0'], axis=1, inplace=True)
music_df
# Out:
#         id                                        제목_가수_장르_가사
# 0        0  그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1        1  사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2        2  나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3        3  내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4        4  사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...    ...                                                ...
# 6521  6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
# [6526 rows x 2 columns]

# %%
music_df.rename(columns={"제목_가수_장르_가사":'summary'}, inplace=True)
music_df
# Out:
#         id                                            summary
# 0        0  그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1        1  사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2        2  나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3        3  내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4        4  사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...    ...                                                ...
# 6521  6521  paranoid (Feat. DEAN)Mokyo포크/블루스So I got paran...
# 6522  6522  꿈 (Still I Love You)김수영인디음악, 포크/블루스어젯밤에 불안했던 무...
# 6523  6523  서투른 고백그_냥인디음악, 포크/블루스보랏빛 하늘에 문득 생각이 들었어 나의 마음을...
# 6524  6524  연가정우인디음악, 포크/블루스이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨...
# 6525  6525  소등109인디음악, 포크/블루스오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시...
#
# [6526 rows x 2 columns]

# %%
book_df = pd.read_csv('/Users/baaam771/Desktop/code/model/book_del_stopword.csv')
book_df
# Out:
#        Unnamed: 0     id                                            summary
# 0               0      1        리스트 고독한가운데 신의 축복 마스트미디어 편집부 지은이마스트미디어예술대중문화
# 1               1      2  거짓말이다  꽃다발 상품권 세트김탁환 지은이북스피어김탁환 작가의 거짓말이다와 꽃다발...
# 2               2      3  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 3               3      4  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 4               4      5  엘르  형  표지   재현 부록없음  주요기사   재현 김태리 여자아이들 민니 르세...
# ...           ...    ...                                                ...
# 77509       77509  79422        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 77510       77510  79423            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 77511       77511  79424  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 77512       77512  79425  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 77513       77513  79476  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [77514 rows x 3 columns]

# %%
id_list = []
for i in range(6526,84040):
    id_list.append(i)
book_df['id'] = id_list
book_df
# Out:
#        Unnamed: 0     id                                            summary
# 0               0   6526        리스트 고독한가운데 신의 축복 마스트미디어 편집부 지은이마스트미디어예술대중문화
# 1               1   6527  거짓말이다  꽃다발 상품권 세트김탁환 지은이북스피어김탁환 작가의 거짓말이다와 꽃다발...
# 2               2   6528  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 3               3   6529  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 4               4   6530  엘르  형  표지   재현 부록없음  주요기사   재현 김태리 여자아이들 민니 르세...
# ...           ...    ...                                                ...
# 77509       77509  84035        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 77510       77510  84036            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 77511       77511  84037  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 77512       77512  84038  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 77513       77513  84039  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [77514 rows x 3 columns]

# %%
book_df.drop(['Unnamed: 0'], axis=1, inplace=True)
book_df
# Out:
#           id                                            summary
# 0       6526        리스트 고독한가운데 신의 축복 마스트미디어 편집부 지은이마스트미디어예술대중문화
# 1       6527  거짓말이다  꽃다발 상품권 세트김탁환 지은이북스피어김탁환 작가의 거짓말이다와 꽃다발...
# 2       6528  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 3       6529  헌금봉투 주일헌금  속매  비전북 편집부 지은이비전북비전아트 고급캘리헌금봉투는 캘리...
# 4       6530  엘르  형  표지   재현 부록없음  주요기사   재현 김태리 여자아이들 민니 르세...
# ...      ...                                                ...
# 77509  84035        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 77510  84036            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 77511  84037  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 77512  84038  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 77513  84039  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [77514 rows x 2 columns]

# %%
concat_df = pd.concat([music_df, book_df])
concat_df
# Out:
#           id                                            summary
# 0          0  그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1          1  사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2          2  나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3          3  내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4          4  사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...      ...                                                ...
# 77509  84035        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 77510  84036            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 77511  84037  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 77512  84038  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 77513  84039  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [84040 rows x 2 columns]

# %%
concat_df.reset_index(inplace=True)
concat_df
# Out:
#        index     id                                            summary
# 0          0      0  그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1          1      1  사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2          2      2  나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3          3      3  내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4          4      4  사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...      ...    ...                                                ...
# 84035  77509  84035        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 84036  77510  84036            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 84037  77511  84037  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 84038  77512  84038  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 84039  77513  84039  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [84040 rows x 3 columns]

# %%
concat_df.drop(['index'], inplace=True, axis=1)
concat_df
# Out:
#           id                                            summary
# 0          0  그때 그 순간 그대로 (그그그)WSG워너비 (가야G)발라드잘 지냈지? 조금은 어색해...
# 1          1  사랑인가 봐멜로망스발라드, 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 ...
# 2          2  나의 X에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의...
# 3          3  내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4          4  사랑은 늘 도망가임영웅발라드, 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이...
# ...      ...                                                ...
# 84035  84035        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 84036  84036            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 84037  84037  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 84038  84038  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 84039  84039  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [84040 rows x 2 columns]

# %%
concat_df.to_csv('concat_summary.csv')

# %%
from konlpy.tag import Mecab
from tqdm import tqdm

# 불용어 가져오기
stopwords = []
with open("data/hangul_stopword.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        line = line.strip()  # 줄 끝의 줄 바꿈 문자를 제거한다.
        line = line.replace('\n', '')
        stopwords.append(line)

# %%
concat_df['summary'] = concat_df['summary'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "")
concat_df
# Out:
# /var/folders/b5/__960gvn4nd3bhxr41c7x3fw0000gn/T/ipykernel_3094/3264782026.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   concat_df['summary'] = concat_df['summary'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "")
#           id                                            summary
# 0          0  그때 그 순간 그대로 그그그워너비 가야발라드잘 지냈지 조금은 어색해 요즘 좋아 보여...
# 1          1  사랑인가 봐멜로망스발라드 국내드라마너와 함께 하고 싶은 일들을 상상하는 게 요즘 내...
# 2          2  나의 에게경서발라드우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 ...
# 3          3  내가 아니라도주호발라드사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 ...
# 4          4  사랑은 늘 도망가임영웅발라드 국내드라마눈물이 난다 이 길을 걸으면 그 사람 손길이 ...
# ...      ...                                                ...
# 84035  84035        희망을 부르는 어린이 가을  어린이 인문교양지인디고 서원 지은이인디고서원어린이
# 84036  84036            상담 및 심리교육 프로그램 개발  제판김창대 지은이학지사대학교재전문서적
# 84037  84037  조각 너에게 주고 싶은 나의 한 조각이세설 권형준 해운 공윤경 김경아 황윤이 임제리...
# 84038  84038  삼봉파 선도채성훈 김대훈 지은이다크아트삼봉파 선도는 인간이 가진 근원적인 욕구 중 ...
# 84039  84039  페이스북 광고  타겟마케팅  하루 원으로 만명 도달하기페꼼마 이종근 지은이리텍콘텐츠...
#
# [84040 rows x 2 columns]

# %%
mecab = Mecab()
corpus_list = []

# %%
# summary 전처리
# 한글 제외 나머지 문자 제거

for index, row in tqdm(concat_df.iterrows(), total=len(concat_df)):
    text = row['summary']
    tokenized_sentence = mecab.morphs(text)
    stopwords_removed_sentence = [
        word for word in tokenized_sentence if not word in stopwords]  # 불용어 제거
    corpus_list.append(stopwords_removed_sentence)
concat_df['summary'] = corpus_list
# Out:
# 100%|██████████| 84040/84040 [00:35<00:00, 2376.69it/s]

# %%
concat_df
# Out:
#           id                                            summary
# 0          0  [그때, 순간, 그대로, 워너비, 가야, 발라드, 지냈, 조금, 은, 어색, 해, ...
# 1          1  [사랑, 인가, 봐, 멜, 로망스, 발라드, 국내, 드라마, 너, 와, 함께, 고,...
# 2          2  [의, 에게, 경서, 발라드, 만날래, 예쁘, 게, 빛나, 던, 모든, 추억, 너무...
# 3          3  [라도, 주호, 발라드, 사랑, 었, 다, 별거, 던, 하루, 에, 빛, 돼준, 단...
# 4          4  [사랑, 은, 늘, 도망가, 임영웅, 발라드, 국내, 드라마, 눈물, 난다, 길, ...
# ...      ...                                                ...
# 84035  84035  [희망, 을, 부르, 는, 어린이, 가을, 어린이, 인문, 교양, 인디고, 서원, ...
# 84036  84036  [상담, 및, 심리, 교육, 프로그램, 개발, 제, 판, 김창대, 지은, 학지, 사...
# 84037  84037  [조각, 너, 에게, 고, 은, 의, 조각, 세설, 권형준, 해운, 공, 윤경, 김...
# 84038  84038  [삼, 봉파, 선, 도, 채, 성훈, 김대훈, 지은, 다크, 아트, 삼, 봉파, 선...
# 84039  84039  [페이스북, 광고, 타, 겟, 마케팅, 하루, 으로, 만, 도달, 기, 페꼼마, 이...
#
# [84040 rows x 2 columns]

# %%
concat_df.to_csv('concat_mecab.csv')

# %%
import pandas as pd
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from konlpy.tag import Mecab
from tqdm import tqdm
import h5py
import os

# %%
word2vec_model = Word2Vec.load('/Users/baaam771/Desktop/code/model/data/ko.bin')

# %%
# 모델 저장
word2vec_model.wv.save_word2vec_format('data/ko.bin.gz', binary=True)

# %%
word2vec_model = Word2Vec(size=200, window=3, min_count=2, workers=4)

# %%
# 토큰화 전처리가 끝나면 각 단어에 고유한 정수를 맵핑해주는 정수 인코딩(Integer enoding) 작업이 필요하다. 
# 그리고 이 전처리를 위해서는 우선 단어 집합을 만들어주어야 한다! 
# 정의한 필드에 .build_vocab()을 사용하여 단어 집합을 생성할 수 있다.
# Word2Vec 모델을 임베딩 벡터값으로 초기화
word2vec_model.build_vocab(corpus_list)

# %%
# 추가된 단어들에 대한 가중치 업데이트
word2vec_model.intersect_word2vec_format(
    'data/ko.bin.gz', lockf=1.0, binary=True)

# %%
word2vec_model.train(
    corpus_list, total_examples=word2vec_model.corpus_count, epochs=20)
# Out:
# (102781516, 126182440)

# %%
def get_document_vectors(document_list, word2vec_model):
    document_embedding_list = []

    # 각 문서에 대해서
    for line in document_list:
        doc2vec = None
        count = 0
        for word in line:
          # 해당 단어가 존재하는지를 체크
            if word in word2vec_model.wv.vocab:
                count += 1
                # 해당 문서에 있는 모든 단어들의 벡터값을 더한다.
                if doc2vec is None:
                    doc2vec = word2vec_model[word]
                else:
                    doc2vec = doc2vec + word2vec_model[word]

        if doc2vec is not None:
            # 단어 벡터를 모두 더한 벡터의 값을 문서 길이로 나눠준다.
            doc2vec = doc2vec / count
            document_embedding_list.append(doc2vec)

    # 각 문서에 대한 문서 벡터 리스트를 리턴
    return document_embedding_list

# %%
document_embedding_list = get_document_vectors(
    concat_df['summary'], word2vec_model)
# Out:
# /var/folders/b5/__960gvn4nd3bhxr41c7x3fw0000gn/T/ipykernel_26852/1756465902.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   doc2vec = word2vec_model[word]
# /var/folders/b5/__960gvn4nd3bhxr41c7x3fw0000gn/T/ipykernel_26852/1756465902.py:16: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   doc2vec = doc2vec + word2vec_model[word]

# %%
cosine_similarities = cosine_similarity(
    document_embedding_list, document_embedding_list)

# %%
music_for_concat = pd.read_csv('/Users/baaam771/Desktop/code/model/music_for_concat.csv')
music_for_concat
# Out:
#       Unnamed: 0    id  melon_music_code                     제목            가수  \
# 0              0     0          35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)
# 1              1     1          34657844                 사랑인가 봐          멜로망스
# 2              2     2          34943312                 나의 X에게            경서
# 3              3     3          34787226                내가 아니라도            주호
# 4              4     4          34061322              사랑은 늘 도망가           임영웅
# ...          ...   ...               ...                    ...           ...
# 6521        6521  6521          33151943  paranoid (Feat. DEAN)         Mokyo
# 6522        6522  6522          33509132   꿈 (Still I Love You)           김수영
# 6523        6523  6523          33572058                 서투른 고백           그_냥
# 6524        6524  6524          32613630                     연가            정우
# 6525        6525  6525          33221082                     소등           109
#
#                 장르                                                 가사
# 0              발라드  잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1       발라드, 국내드라마  너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2              발라드  우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3              발라드  사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4       발라드, 국내드라마  눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...            ...                                                ...
# 6521        포크/블루스  So I got paranoid with the drums I ain’t got t...
# 6522  인디음악, 포크/블루스  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  인디음악, 포크/블루스  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  인디음악, 포크/블루스  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  인디음악, 포크/블루스  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
# [6526 rows x 7 columns]

# %%
music_for_concat.drop(['Unnamed: 0'], inplace=True, axis=1)
music_for_concat
# Out:
#         id  melon_music_code                     제목            가수  \
# 0        0          35383397      그때 그 순간 그대로 (그그그)  WSG워너비 (가야G)
# 1        1          34657844                 사랑인가 봐          멜로망스
# 2        2          34943312                 나의 X에게            경서
# 3        3          34787226                내가 아니라도            주호
# 4        4          34061322              사랑은 늘 도망가           임영웅
# ...    ...               ...                    ...           ...
# 6521  6521          33151943  paranoid (Feat. DEAN)         Mokyo
# 6522  6522          33509132   꿈 (Still I Love You)           김수영
# 6523  6523          33572058                 서투른 고백           그_냥
# 6524  6524          32613630                     연가            정우
# 6525  6525          33221082                     소등           109
#
#                 장르                                                 가사
# 0              발라드  잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...
# 1       발라드, 국내드라마  너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...
# 2              발라드  우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 3              발라드  사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...
# 4       발라드, 국내드라마  눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# ...            ...                                                ...
# 6521        포크/블루스  So I got paranoid with the drums I ain’t got t...
# 6522  인디음악, 포크/블루스  어젯밤에 불안했던 무서웠던 꿈을 꾸고 너에게 달려가 봤을 때 모든게 변함이 없네 그...
# 6523  인디음악, 포크/블루스  보랏빛 하늘에 문득 생각이 들었어 나의 마음을 전하고 싶어진거야 서투른 나의 고백이...
# 6524  인디음악, 포크/블루스  이제 널 안고 그 무렵을 내려놓고 어깨에 힘을 풀고 숨 들이마시고 눈 감지 말고 넝...
# 6525  인디음악, 포크/블루스  오늘도 어김없이 집에 가는 언덕 다리가 아파와서 잠시 앉을 곳을 찾았어 주변을 둘러...
#
# [6526 rows x 6 columns]

# %%
sim_scores = list(enumerate(cosine_similarities[13043]))
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

# 가장 유사한 값 10개의 인덱스
book_indices = [i[0] for i in sim_scores if i[0] <6526]
book_indices = book_indices[1:11]

# 전체 데이터프레임에서 해당 인덱스의 행만 추출. 10개의 행을 가진다.
recommend = music_for_concat.iloc[book_indices].reset_index(drop=True)
recommend
# Out:
#      id  melon_music_code                 제목                 가수  \
# 0  5591          34443400               하이웨이                하현상
# 1  2945           5763104                명사수                정상수
# 2  5965           5466964               그리워라               10CM
# 3  5887          35207587               STAR        STAYC(스테이씨)
# 4  2284           1114595  몽환의 숲 (Feat. 이루마)            키네틱 플로우
# 5  2815            518046      Gloomy Sunday            MC 스나이퍼
# 6  5044          30105621  나비잠 (Sweet Dream)           김희철, 민경훈
# 7  6353          31454150      Bye my summer       유지희 (Yujihi)
# 8  5263           1649191               한사람만  FTISLAND (FT아일랜드)
# 9  4839          35360370                 잔향            비비 (BB)
#
#                장르                                                 가사
# 0            록/메탈  채울 수 없는 공허함이 달리는 이곳 그중 어떤 날은 하루가 좀 서글퍼지는 그만둬버릴...
# 1      랩/힙합, 인디음악  CHECK THIS OUT 나는 정상수 백발백중 하는 명사수 부산진구 유명 가수 일...
# 2    인디음악, 포크/블루스  그리워라  가끔씩 자꾸 니 생각이 나서 잠도 오지를 않고 마음만 괜히 심란하고 우리...
# 3   포크/블루스, 국내드라마  쏟아지는 밤하늘의 별 하나하나 세다 지칠 때까지 날 따라오는 달을 보다가 잠이 들어...
# 4            랩/힙합  이 새벽을 비추는 초생달 오감보다 생생한 육감의 세계로 보내주는 푸르고 투명한 파랑...
# 5            랩/힙합  우울한 오후 사랑의 질투는 실수를 연발해 참희 부서진 그대의 눈물 세상을 차게 적시...
# 6            록/메탈  어느덧 흘러간 시간을 수놓을 수 있는 밤 짧지 않던 세월 서로가 가까워진 지금을 웃...
# 7    인디음악, 포크/블루스  우리는 언제부터인지 말을 삼켰고 왠지 어색해지고 조금 불편해졌어 소중했던 것들이 의...
# 8            록/메탈  한 여자밖에 모르고 한 여자만을 사랑합니다 그게 부담될 줄 모르고 떠날 이유를 준 ...
# 9  R&B/Soul, 인디음악  I don't know 아직도 나는 모르겠어 하나도 아마 착각 일지도 다른 사람 품...

# %%
sim_scores = list(enumerate(cosine_similarities[30241]))
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
# sim_scores = sim_scores[1:201]

# 가장 유사한 값 10개의 인덱스
book_indices = [i[0] for i in sim_scores if i[0] <6526]
book_indices = book_indices[1:11]

# 전체 데이터프레임에서 해당 인덱스의 행만 추출. 10개의 행을 가진다.
recommend = music_for_concat.iloc[book_indices].reset_index(drop=True)
recommend
# Out:
#      id  melon_music_code                                    제목  \
# 0  5965           5466964                                  그리워라
# 1  5887          35207587                                  STAR
# 2  2284           1114595                     몽환의 숲 (Feat. 이루마)
# 3  2932          33115808  부어라 비워라 (Tricker) (Prod. GroovyRoom)
# 4  3048          31019585   이로한 (Feat. ELO, Jessi) (Prod. Padi)
# 5  5263           1649191                                  한사람만
# 6  2945           5763104                                   명사수
# 7  2975          34366014            +82 (Prod. 다이나믹 듀오, THAMA)
# 8  6408          31011959               봄날에 만나자 (Acoustic Ver.)
# 9  2815            518046                         Gloomy Sunday
#
#                                                   가수             장르  \
# 0                                               10CM   인디음악, 포크/블루스
# 1                                        STAYC(스테이씨)  포크/블루스, 국내드라마
# 2                                            키네틱 플로우           랩/힙합
# 3                                   머쉬베놈 (MUSHVENOM)           랩/힙합
# 4                                       Rohann (이로한)           랩/힙합
# 5                                  FTISLAND (FT아일랜드)           록/메탈
# 6                                                정상수     랩/힙합, 인디음악
# 7  팔로알토 (Paloalto), 기리보이, 다이나믹 듀오, 저스디스 (JUSTHIS)...           랩/힙합
# 8                                                 한올   인디음악, 포크/블루스
# 9                                            MC 스나이퍼           랩/힙합
#
#                                                   가사
# 0  그리워라  가끔씩 자꾸 니 생각이 나서 잠도 오지를 않고 마음만 괜히 심란하고 우리...
# 1  쏟아지는 밤하늘의 별 하나하나 세다 지칠 때까지 날 따라오는 달을 보다가 잠이 들어...
# 2  이 새벽을 비추는 초생달 오감보다 생생한 육감의 세계로 보내주는 푸르고 투명한 파랑...
# 3  자유에서 태어나 자유를 위해서 깨어나 보이는 태연함 좀 먹어버린 내 시간과 세상아 ...
# 4  2000년 6월 하고도 4일 평범한 집안의 평범한 아이 강원도 강릉 어느 곳에서 시...
# 5  한 여자밖에 모르고 한 여자만을 사랑합니다 그게 부담될 줄 모르고 떠날 이유를 준 ...
# 6  CHECK THIS OUT 나는 정상수 백발백중 하는 명사수 부산진구 유명 가수 일...
# 7  내가 어디 있건 뿌리는 당연히 82번 지켜, 의심받을 때도 믿어, 역힙꼰 역사의 산...
# 8  봄이면 네가 찾아올까 햇살에 눈이 녹듯이 그렇게 따뜻한 봄날이 다시 또 돌고 돌아 ...
# 9  우울한 오후 사랑의 질투는 실수를 연발해 참희 부서진 그대의 눈물 세상을 차게 적시...
